# %%
import numpy as np
import seabirdfilehandler as fh

# %%
cnv = fh.CnvFile('seabird_example_data/cnv/basic_emb.cnv')
cnv.parameters['prDM'].data
# Out:
# array([ 1.149,  1.197,  1.197, ..., 23.563, 23.46 , 23.563], shape=(3067,))

# %%
def bin_average_array(
    cnv_file,
    bin_variable: str,
    bin_size: float,
): 
    _dataset = cnv_file

    while(data in cnv):
        paramter = 
        x = np.array(cnv_file.parameters[paramter].data)
        
        bin_value = np.array(cnv_file.parameters[bin_variable].data)
        bin_min = bin_size / 2.0
        control_max = np.amax(bin_value)
        bin_max = control_max - ((bin_min + control_max) % bin_size) + bin_size 
        bin1 = np.arange(start=bin_min, stop=bin_max + bin_size, step=bin_size)
        
        
        print(bin_min,bin_max,control_max,bin1)
    
    
        
        binned_data = np.digitize(x,bin1)
        cnv_file.parameters[parameter].data = binned_data + 1


        
    return binned_data

# %%
bin = bin_average_array(
    cnv_file=cnv,
    bin_variable = 'prDM',
    bin_size = 1
)
bin
# Out:
# 0.5 24.5 23.61 [ 0.5  1.5  2.5  3.5  4.5  5.5  6.5  7.5  8.5  9.5 10.5 11.5 12.5 13.5
#  14.5 15.5 16.5 17.5 18.5 19.5 20.5 21.5 22.5 23.5 24.5]
# array([4, 4, 4, ..., 4, 4, 4], shape=(3067,))

# %%
cnv.parameters['t090C'].data
# Out:
# array([5, 5, 5, ..., 5, 5, 5], shape=(3067,))
